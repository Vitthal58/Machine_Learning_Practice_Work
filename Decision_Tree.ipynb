# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
features = ["pclass" , "sex" , "age" , "embarked" , "fare"]
target = ["survived"]

# %%
# filling null values
from sklearn.impute import SimpleImputer

imp_age = SimpleImputer(strategy = "median")
titanic[["age"]] = imp_age.fit_transform(titanic[["age"]])

imp_embarked = SimpleImputer(strategy = "most_frequent")
titanic[["embarked"]] = imp_embarked.fit_transform(titanic[["embarked"]])

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# encoding
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
titanic["sex"] = le.fit_transform(titanic["sex"])
titanic["embarked"] = le.fit_transform(titanic["embarked"])

# %%
X = titanic[features]
y = titanic[target]

X_train , X_test , y_train , y_test = train_test_split(
    X , y , test_size = 0.3 , random_state = 42
)

# %%
# decision tree classifier
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred = DT.predict(X_test)

print("Accuraccy :" , accuracy_score(y_test , y_pred))
# Out:
# Accuraccy : 0.7574626865671642

# %%
plt.figure(figsize = (18 , 10))

from sklearn.tree import plot_tree

plot_tree( DT, feature_names = titanic[features].columns , class_names = ["Died" , "survived"] , filled = True, max_depth = 2 )

plt.tight_layout() 
plt.show()

# %% [markdown]
# # post prunning

# %%
path = DT.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas

# %% [markdown]
# ccp_alphas

# %%
trees = []
for alpha in ccp_alphas:
    DT = DecisionTreeClassifier(max_depth = 4 , ccp_alpha = alpha)
    DT.fit(X_train , y_train)

    acc = DT.score(X_test , y_test)

    print(f"CCP alpha = {alpha} , Accuracy = {acc}")
    trees.append((DT , alpha))
# Out:
# CCP alpha = 0.0 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0001337613697164259 , Accuracy = 0.8246268656716418
# CCP alpha = 0.00013376136971642635 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0002293052052281582 , Accuracy = 0.8246268656716418
# CCP alpha = 0.00032102728731942215 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0004840887665927798 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0005350454788657034 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0005350454788657034 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0005350454788657034 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0006274624252152341 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0006420545746388443 , Accuracy = 0.8246268656716418
# CCP alpha = 0.000777089862162093 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0008560727661851258 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0009363295880149813 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0009630818619582662 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0009630818619582662 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0009630818619582662 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0010165864098448365 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0010419306693700559 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0010477973961120041 , Accuracy = 0.8246268656716418
# CCP alpha = 0.001070090957731407 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0010923845193508116 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0011592652042090247 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0012352013957150406 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0012372926698769394 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0012964563526361283 , Accuracy = 0.8246268656716418
# CCP alpha = 0.001322105132559456 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0013356299227183569 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0013758312313689523 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0013758312313689523 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0013970834250149496 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0014322755895789592 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0014414547604967446 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0014981273408239697 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0015048154093097914 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0015159621901194938 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0015218395836373363 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0017121455323702516 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0018344416418252694 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0019011956233298058 , Accuracy = 0.8246268656716418
# CCP alpha = 0.001956737751280288 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0020064205457463887 , Accuracy = 0.8246268656716418
# CCP alpha = 0.002140181915462814 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0023347439077776163 , Accuracy = 0.8246268656716418
# CCP alpha = 0.002407704654895666 , Accuracy = 0.8246268656716418
# CCP alpha = 0.002608346709470305 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0026329157518619056 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0027860582435221253 , Accuracy = 0.8246268656716418
# CCP alpha = 0.002801692689333137 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0028437916060074426 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0028892455858748004 , Accuracy = 0.8246268656716418
# CCP alpha = 0.0029962546816479393 , Accuracy = 0.8246268656716418
# CCP alpha = 0.003024121633672195 , Accuracy = 0.8246268656716418
# CCP alpha = 0.004311437433899903 , Accuracy = 0.8208955223880597
# CCP alpha = 0.004952992432928227 , Accuracy = 0.8059701492537313
# CCP alpha = 0.005778491171749599 , Accuracy = 0.8097014925373134
# CCP alpha = 0.0058943069167090405 , Accuracy = 0.8097014925373134
# CCP alpha = 0.007424803679674685 , Accuracy = 0.8097014925373134
# CCP alpha = 0.012361984901593084 , Accuracy = 0.7723880597014925
# CCP alpha = 0.01787674278767723 , Accuracy = 0.7723880597014925
# CCP alpha = 0.040650744549143095 , Accuracy = 0.7910447761194029
# CCP alpha = 0.13235809539273619 , Accuracy = 0.585820895522388

# %%
best_alpha = 0
best_acc = 0

for DT , alpha in trees:
    curr_acc = DT.score(X_test , y_test)
    if curr_acc > best_acc:
        best_acc = curr_acc
        best_alpha = alpha

# %%
print(f"Best Accuracy of model is {best_acc} & alpha = {best_alpha}")
# Out:
# Best Accuracy of model is 0.8246268656716418 & alpha = 0.0

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.datasets import load_diabetes

df = load_diabetes(as_frame = True).frame

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
X = df.drop(columns = ["target"] , axis = 1)
y = df["target"]

X_train , X_test , y_train , y_test = train_test_split(
    X , y , test_size = 0.3 , random_state = 42
)

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth = 7 , min_samples_leaf = 20)
model.fit(X_train , y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, min_samples_leaf=20)

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)
print("MSE :" , mean_squared_error(y_test , y_pred))
# Out:
# MSE : 3177.664925233041

# %%
# post prunning

path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas


trees = []
for alpha in ccp_alphas:
    model = DecisionTreeRegressor(max_depth = 4 , ccp_alpha = alpha)
    model.fit(X_train , y_train)

    y_pred = model.predict(X_test)

    print(f"CCP alpha = {alpha} , MSE = {mean_squared_error(y_test , y_pred)}")
    trees.append((model , alpha))
# Out:
# CCP alpha = 0.0 , MSE = 3656.6870474838197
# CCP alpha = 0.8559870550161812 , MSE = 3651.06674673194
# CCP alpha = 6.990291262135923 , MSE = 3676.690806882316
# CCP alpha = 20.593092547404055 , MSE = 3496.7245128311556
# CCP alpha = 38.45145631067961 , MSE = 3511.279024109351
# CCP alpha = 78.371859889587 , MSE = 3585.7740215857416
# CCP alpha = 93.9404098858405 , MSE = 3696.579211615812
# CCP alpha = 94.00543851431632 , MSE = 3710.3005316402705
# CCP alpha = 94.03962542312098 , MSE = 3803.463705704157
# CCP alpha = 112.03010222427713 , MSE = 3788.1455444658377
# CCP alpha = 119.09208982923042 , MSE = 3675.9467308910776
# CCP alpha = 126.24659235440458 , MSE = 3265.1012945336884
# CCP alpha = 207.33397855516478 , MSE = 3479.644254558814
# CCP alpha = 434.19302235262944 , MSE = 3546.741044954467
# CCP alpha = 436.3442287203411 , MSE = 4280.762895394589
# CCP alpha = 1835.2873844480928 , MSE = 5432.886351282108

# %%
best_alpha  = 0
best_MSE = 10000

for model , alpha in trees:
    model.fit(X_train , y_train)
    y_pred = model.predict(X_test)
    MSE = mean_squared_error(y_test , y_pred)
    if MSE < best_MSE:
        best_MSE = MSE
        best_alpha = alpha

print(f"MSE = {best_MSE} for alpha = {best_alpha}")
# Out:
# MSE = 3265.1012945336884 for alpha = 126.24659235440458
